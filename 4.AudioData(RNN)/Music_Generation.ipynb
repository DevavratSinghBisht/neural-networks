# %% [markdown]
# # Music Generation using RNN

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
tf.device(device_name)
# Out:
# Found GPU at: /device:GPU:0

# %% [markdown]
# ## Importing Packages

# %%
pip install mido
# Out:
# Collecting mido
#   Downloading https://files.pythonhosted.org/packages/20/0a/81beb587b1ae832ea6a1901dc7c6faa380e8dd154e0a862f0a9f3d2afab9/mido-1.2.9-py2.py3-none-any.whl (52kB)
#      |████████████████████████████████| 61kB 3.8MB/s
# Installing collected packages: mido
# Successfully installed mido-1.2.9

# %%
from mido import MidiFile, MidiTrack, Message
from tensorflow.keras.layers import LSTM, Dense, Activation, Dropout, Flatten
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from sklearn.preprocessing import MinMaxScaler
import numpy as np
import mido

# %% [markdown]
# ## Loading Data
# Our Sound data is in MIDI (.mid) format.

# %%
mid = MidiFile('/content/drive/MyDrive/Study/DL/RNN/Music Generation/allegroconspirito.mid') # a Mozart piece

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# Here we extract the note value, velocity and the timing from the midi file and form an array of all the musical notes present in the music file.

# %% [markdown]
# ### Extracting Data from MIDI file

# %%
# list of all the note values, veloctiy and timing
notes = []

# we are calculating time here coz we want to cover the time of some meta messages in the file
# while we are skipping them for note and velocity
time = 0.0  # current time
prev = 0.0  # time of previous note

for msg in mid:
	### this time is in seconds, not ticks
	time += msg.time

  # excluding meta message here
	if not msg.is_meta:

		#only interested in piano channel
		if msg.channel == 0:

			if msg.type == 'note_on':

				# note in vector form to train on
				note = msg.bytes()
     
				# note message conntains [type, note, velocity], but we are only interested in 
        # [note, velocity, time], tere for we will be extracting note and velocity and
        # appending timing of the musical note
        # observe that the 
        # timing of musical note = time till ucrrent note - time of previous note
				# therefore, timing of musical note = time - prev

				note = note[1:]
				note.append(time-prev)
				prev = time
				notes.append(note)

# %% [markdown]
# ### Scaling data into range of 0, 1

# %%
t = []
for note in notes:
  # domain knowledge required for chossing the numbers 24 and 88,
  # a general method would be substracting the whole set by the minimum number
  # then dividing the whole set by new maximum fromed
	note[0] = (note[0]-24)/88

  # same as above... domain knowledge required   
	note[1] = note[1]/127  
	t.append(note[2])
 
# here we are uing the general methody
# calculating the maximum value of time and then dividing by it
# the minimum value is 0 thus no need of substraction
# scale based on the biggest time of any note
max_t = max(t)
for note in notes:
	note[2] = note[2]/max_t

# %% [markdown]
# ### Creating Data Labels

# %% [markdown]
# * We will now make a an array of musical notes in X and corresponding next musical notes in Y.
# * n_prev is the length of musical notes used to predict the next muscial note.
# * we will also save a seed to generate the music later.

# %%
X = []
Y = []
n_prev = 30
# n_prev notes to predict the (n_prev+1)th note
for i in range(len(notes)-n_prev):
	x = notes[i:i+n_prev]
	y = notes[i+n_prev]
	X.append(x)
	Y.append(y)
# save a seed to do prediction later
seed = notes[0:n_prev]

# %% [markdown]
# ## Model Building

# %% [markdown]
# * We are going to make a Sequential model.
# * We will use two LSTM layers.
# * After each LSTM we are using a dropout layer.
# * Finally the output will be given by a dense layer

# %%
model = Sequential()
model.add(LSTM(128, input_shape=(n_prev, 3), return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(64, return_sequences=False))
model.add(Dropout(0.2))
model.add(Flatten())
model.add(Dense(3))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 30, 128)           67584
# _________________________________________________________________
# dropout (Dropout)            (None, 30, 128)           0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 64)                49408
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# flatten (Flatten)            (None, 64)                0
# _________________________________________________________________
# dense (Dense)                (None, 3)                 195
# =================================================================
# Total params: 117,187
# Trainable params: 117,187
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Model Training

# %%
# hyper parameters
batch_size = 256
epochs = 400

# %%
model.compile(loss='mse', optimizer='adam')
model.fit(X, Y, batch_size=batch_size, epochs=epochs, verbose=1)
# Out:
# Epoch 1/400
# 24/24 [==============================] - 8s 7ms/step - loss: 0.0428
# Epoch 2/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0201
# Epoch 3/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0195
# Epoch 4/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0194
# Epoch 5/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0195
# Epoch 6/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0190
# Epoch 7/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0187
# Epoch 8/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0187
# Epoch 9/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0183
# Epoch 10/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0184
# Epoch 11/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0182
# Epoch 12/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0178
# Epoch 13/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0178
# Epoch 14/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0177
# Epoch 15/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0176
# Epoch 16/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0173
# Epoch 17/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0175
# Epoch 18/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0175
# Epoch 19/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0173
# Epoch 20/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0168
# Epoch 21/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0167
# Epoch 22/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0165
# Epoch 23/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0169
# Epoch 24/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0165
# Epoch 25/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0166
# Epoch 26/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0164
# Epoch 27/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0163
# Epoch 28/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0162
# Epoch 29/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0161
# Epoch 30/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0160
# Epoch 31/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0158
# Epoch 32/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0154
# Epoch 33/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0157
# Epoch 34/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0154
# Epoch 35/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0157
# Epoch 36/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0156
# Epoch 37/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0159
# Epoch 38/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0155
# Epoch 39/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0153
# Epoch 40/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0157
# Epoch 41/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0149
# Epoch 42/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0153
# Epoch 43/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0150
# Epoch 44/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0152
# Epoch 45/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0149
# Epoch 46/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0147
# Epoch 47/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0144
# Epoch 48/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0147
# Epoch 49/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0145
# Epoch 50/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0145
# Epoch 51/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0145
# Epoch 52/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0148
# Epoch 53/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0151
# Epoch 54/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0145
# Epoch 55/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0145
# Epoch 56/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0145
# Epoch 57/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0145
# Epoch 58/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0143
# Epoch 59/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0144
# Epoch 60/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0143
# Epoch 61/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0144
# Epoch 62/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0142
# Epoch 63/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0140
# Epoch 64/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0139
# Epoch 65/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0138
# Epoch 66/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0137
# Epoch 67/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0138
# Epoch 68/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0136
# Epoch 69/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0136
# Epoch 70/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0134
# Epoch 71/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0135
# Epoch 72/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0133
# Epoch 73/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0132
# Epoch 74/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0133
# Epoch 75/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0135
# Epoch 76/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0131
# Epoch 77/400
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0135
# Epoch 78/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0132
# Epoch 79/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0127
# Epoch 80/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0130
# Epoch 81/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0129
# Epoch 82/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0124
# Epoch 83/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0129
# Epoch 84/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0127
# Epoch 85/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0125
# Epoch 86/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0123
# Epoch 87/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0125
# Epoch 88/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0121
# Epoch 89/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0119
# Epoch 90/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0123
# Epoch 91/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0121
# Epoch 92/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0118
# Epoch 93/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0117
# Epoch 94/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0116
# Epoch 95/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0116
# Epoch 96/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0118
# Epoch 97/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0121
# Epoch 98/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0112
# Epoch 99/400
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0115
# Epoch 100/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0113
# Epoch 101/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0112
# Epoch 102/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0111
# Epoch 103/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0112
# Epoch 104/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0113
# Epoch 105/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0108
# Epoch 106/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0109
# Epoch 107/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0106
# Epoch 108/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0105
# Epoch 109/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0106
# Epoch 110/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0106
# Epoch 111/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0105
# Epoch 112/400
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0103
# Epoch 113/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0102
# Epoch 114/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0101
# Epoch 115/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0100
# Epoch 116/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0098
# Epoch 117/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0101
# Epoch 118/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0096
# Epoch 119/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0097
# Epoch 120/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0096
# Epoch 121/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0096
# Epoch 122/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0096
# Epoch 123/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0094
# Epoch 124/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0094
# Epoch 125/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0099
# Epoch 126/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0094
# Epoch 127/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0093
# Epoch 128/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0090
# Epoch 129/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0090
# Epoch 130/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0092
# Epoch 131/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0089
# Epoch 132/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0088
# Epoch 133/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0086
# Epoch 134/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0090
# Epoch 135/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0091
# Epoch 136/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0086
# Epoch 137/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0087
# Epoch 138/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0095
# Epoch 139/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0086
# Epoch 140/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0085
# Epoch 141/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0083
# Epoch 142/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0082
# Epoch 143/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0085
# Epoch 144/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0082
# Epoch 145/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0082
# Epoch 146/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0080
# Epoch 147/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0080
# Epoch 148/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0079
# Epoch 149/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0080
# Epoch 150/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0076
# Epoch 151/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0079
# Epoch 152/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0074
# Epoch 153/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0073
# Epoch 154/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0075
# Epoch 155/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0079
# Epoch 156/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0075
# Epoch 157/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0072
# Epoch 158/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0073
# Epoch 159/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0072
# Epoch 160/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0073
# Epoch 161/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0072
# Epoch 162/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0071
# Epoch 163/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0072
# Epoch 164/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0068
# Epoch 165/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0069
# Epoch 166/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0065
# Epoch 167/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0065
# Epoch 168/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0069
# Epoch 169/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0066
# Epoch 170/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0065
# Epoch 171/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0066
# Epoch 172/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0067
# Epoch 173/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0066
# Epoch 174/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0062
# Epoch 175/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0059
# Epoch 176/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0061
# Epoch 177/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0061
# Epoch 178/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0061
# Epoch 179/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0060
# Epoch 180/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0061
# Epoch 181/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0060
# Epoch 182/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0058
# Epoch 183/400
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0059
# Epoch 184/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0056
# Epoch 185/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0056
# Epoch 186/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0056
# Epoch 187/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0055
# Epoch 188/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0054
# Epoch 189/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0055
# Epoch 190/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0051
# Epoch 191/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0051
# Epoch 192/400
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0052
# Epoch 193/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0051
# Epoch 194/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0052
# Epoch 195/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0051
# Epoch 196/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0052
# Epoch 197/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0051
# Epoch 198/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0049
# Epoch 199/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0047
# Epoch 200/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0048
# Epoch 201/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0046
# Epoch 202/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0049
# Epoch 203/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0047
# Epoch 204/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0049
# Epoch 205/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0045
# Epoch 206/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0044
# Epoch 207/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0046
# Epoch 208/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0043
# Epoch 209/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0048
# Epoch 210/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0045
# Epoch 211/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0043
# Epoch 212/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0044
# Epoch 213/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0041
# Epoch 214/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0042
# Epoch 215/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0042
# Epoch 216/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0043
# Epoch 217/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0040
# Epoch 218/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0040
# Epoch 219/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0037
# Epoch 220/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0037
# Epoch 221/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0040
# Epoch 222/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0037
# Epoch 223/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0038
# Epoch 224/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0039
# Epoch 225/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0041
# Epoch 226/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0046
# Epoch 227/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0038
# Epoch 228/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0036
# Epoch 229/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0038
# Epoch 230/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0036
# Epoch 231/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0034
# Epoch 232/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0035
# Epoch 233/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0033
# Epoch 234/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0034
# Epoch 235/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0034
# Epoch 236/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0033
# Epoch 237/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0033
# Epoch 238/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0034
# Epoch 239/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0038
# Epoch 240/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0033
# Epoch 241/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0031
# Epoch 242/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0033
# Epoch 243/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0032
# Epoch 244/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0029
# Epoch 245/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0031
# Epoch 246/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0030
# Epoch 247/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0030
# Epoch 248/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0031
# Epoch 249/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0030
# Epoch 250/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0030
# Epoch 251/400
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0029
# Epoch 252/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0029
# Epoch 253/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0029
# Epoch 254/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0029
# Epoch 255/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0027
# Epoch 256/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0027
# Epoch 257/400
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0027
# Epoch 258/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0029
# Epoch 259/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0028
# Epoch 260/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0031
# Epoch 261/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0029
# Epoch 262/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0027
# Epoch 263/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0028
# Epoch 264/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0026
# Epoch 265/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0026
# Epoch 266/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0025
# Epoch 267/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0025
# Epoch 268/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0028
# Epoch 269/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0027
# Epoch 270/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0025
# Epoch 271/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0024
# Epoch 272/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0024
# Epoch 273/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0024
# Epoch 274/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0023
# Epoch 275/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0029
# Epoch 276/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0027
# Epoch 277/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0024
# Epoch 278/400
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0024
# Epoch 279/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0023
# Epoch 280/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0023
# Epoch 281/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0024
# Epoch 282/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0024
# Epoch 283/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0022
# Epoch 284/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0024
# Epoch 285/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0022
# Epoch 286/400
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0026
# Epoch 287/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0024
# Epoch 288/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0022
# Epoch 289/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0022
# Epoch 290/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0021
# Epoch 291/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0022
# Epoch 292/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0021
# Epoch 293/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0029
# Epoch 294/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0024
# Epoch 295/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0023
# Epoch 296/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0022
# Epoch 297/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0020
# Epoch 298/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0020
# Epoch 299/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0019
# Epoch 300/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0021
# Epoch 301/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0018
# Epoch 302/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0021
# Epoch 303/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0019
# Epoch 304/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0020
# Epoch 305/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0020
# Epoch 306/400
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0019
# Epoch 307/400
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0019
# Epoch 308/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0020
# Epoch 309/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0019
# Epoch 310/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0019
# Epoch 311/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0020
# Epoch 312/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0018
# Epoch 313/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0018
# Epoch 314/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0018
# Epoch 315/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0017
# Epoch 316/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0018
# Epoch 317/400
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0017
# Epoch 318/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0018
# Epoch 319/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0018
# Epoch 320/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0017
# Epoch 321/400
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0018
# Epoch 322/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0017
# Epoch 323/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0017
# Epoch 324/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0018
# Epoch 325/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0018
# Epoch 326/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0017
# Epoch 327/400
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0017
# Epoch 328/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0017
# Epoch 329/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0017
# Epoch 330/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 331/400
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0017
# Epoch 332/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 333/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0017
# Epoch 334/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 335/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0018
# Epoch 336/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0018
# Epoch 337/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0017
# Epoch 338/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0017
# Epoch 339/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 340/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0017
# Epoch 341/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0015
# Epoch 342/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 343/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0015
# Epoch 344/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0020
# Epoch 345/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0018
# Epoch 346/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0018
# Epoch 347/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 348/400
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0015
# Epoch 349/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0014
# Epoch 350/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0014
# Epoch 351/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0015
# Epoch 352/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0015
# Epoch 353/400
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0014
# Epoch 354/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 355/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 356/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0015
# Epoch 357/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0015
# Epoch 358/400
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0014
# Epoch 359/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0015
# Epoch 360/400
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0016
# Epoch 361/400
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0015
# Epoch 362/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0025
# Epoch 363/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0018
# Epoch 364/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 365/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0015
# Epoch 366/400
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0014
# Epoch 367/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0015
# Epoch 368/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0015
# Epoch 369/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0014
# Epoch 370/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0015
# Epoch 371/400
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0014
# Epoch 372/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0015
# Epoch 373/400
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0015
# Epoch 374/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0014
# Epoch 375/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0015
# Epoch 376/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0014
# Epoch 377/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 378/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0015
# Epoch 379/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0014
# Epoch 380/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0014
# Epoch 381/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0014
# Epoch 382/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0014
# Epoch 383/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0013
# Epoch 384/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0013
# Epoch 385/400
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0013
# Epoch 386/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0013
# Epoch 387/400
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0015
# Epoch 388/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0014
# Epoch 389/400
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0014
# Epoch 390/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0014
# Epoch 391/400
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0014
# Epoch 392/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0014
# Epoch 393/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0013
# Epoch 394/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0013
# Epoch 395/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0013
# Epoch 396/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0013
# Epoch 397/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0013
# Epoch 398/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0014
# Epoch 399/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0013
# Epoch 400/400
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0012

# %% [markdown]
# ## Making Predictions

# %% [markdown]
# * prediction is a list that will contain our generated notes
# * seed is the seed that we saved earlier to generate music
# * no_of_predictions is the number of musical notes we want to generate
# ------
# What we are going to do is make a loop, we make a prediction for the seed then update the seed by removing the note at earliest time stamp and adding the generated note to the latest time stamp. Now we will use this seed to generate new notes. This process caries on in a loop to generate a sequence of notes.

# %%
prediction = []
x = seed
x = np.expand_dims(x, axis=0)

no_of_predictions = 3000

for i in range(no_of_predictions):
	preds = model.predict(x)
	x = np.squeeze(x)
	x = np.concatenate((x, preds))
	x = x[1:]
	x = np.expand_dims(x, axis=0)
	preds = np.squeeze(preds)
	prediction.append(preds)

# %%
for pred in prediction:

  # coverting back to original range
  # we converted the data into the range of 0, 1 above
  # now we are geeting the data in the range of 0, 1 from the model
  # and have to get the original data from it
  # so we are now multiplying and adding, just oppisite of the opertaion we did above
  
	pred[0] = int(88*pred[0] + 24)
	pred[1] = int(127*pred[1])
	pred[2] *= max_t
  
	# rejecting values that will be out of range
	# domain knowledge and knowledge of MIDI files required to know the range
	if pred[0] < 24:
		pred[0] = 24
	elif pred[0] > 102:
		pred[0] = 102
	if pred[1] < 0:
		pred[1] = 0
	elif pred[1] > 127:
		pred[1] = 127
	if pred[2] < 0:
		pred[2] = 0

# %% [markdown]
# ## Saving Generated Music

# %%
mid = MidiFile()
track = MidiTrack()
mid.tracks.append(track)

for note in prediction:
	# 147 means note_on
	note = np.insert(note, 0, 147)
	bytes = note.astype(int)
	msg = Message.from_bytes(bytes[0:3]) 
	time = int(note[3]/0.001025) # to rescale to midi's delta ticks. arbitrary value for now.
	msg.time = time
	track.append(msg)

mid.save('generated_music.mid')
