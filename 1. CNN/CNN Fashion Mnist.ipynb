# %%
import tensorflow as tf
import keras
from keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense
from keras.datasets import fashion_mnist
from keras.models import Model

import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import numpy as np

# %%
(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()

# %%
print('Shape of X train: ',X_train.shape,'Shape of X train:' , y_train.shape)
print('Shape of X test:', X_test.shape,'Shape of X test:', y_test.shape)
# Out:
# Shape of X train:  (60000, 28, 28) Shape of X train: (60000,)
# Shape of X test: (10000, 28, 28) Shape of X test: (10000,)

# %%
X_train = X_train/255
X_test = X_test/255

channel = 1
img_h , img_w = X_train.shape[1:]

X_train = X_train.reshape(X_train.shape[0], img_h, img_w, channel)
X_test = X_test.reshape(X_test.shape[0], img_h, img_w, channel)

input_shape = (img_h, img_w, channel)

# %%
no_of_classes = 10
y_train_oh = np.eye(no_of_classes)[y_train]
y_test_oh = np.eye(no_of_classes)[y_test]

# %%
index_to_class = {0: 'T-shirt',
                  1: 'Trouser',
                  2: 'Pullover',
                  3: 'Dress',
                  4: 'Coat',
                  5: 'Sandle',
                  6: 'Sirt',
                  7: 'Sneaker',
                  8: 'Bag',
                  9: 'Ankle Boot'}

# %%
input_layer = Input(input_shape)

x = Conv2D(filters=4, kernel_size=5, activation='relu')(input_layer)
x = Conv2D(filters=8, kernel_size=5, strides=(2, 2), activation='relu')(x)
x = Conv2D(filters=16, kernel_size=5, strides=(2, 2), activation='relu')(x)
x = Flatten()(x)
x = Dense(units= 64, activation='relu')(x)
x = Dense(units=10, activation='softmax')(x)

model = Model(inputs=input_layer, outputs=x)

# %%
model.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 24, 24, 4)         104
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 10, 10, 8)         808
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 3, 3, 16)          3216
# _________________________________________________________________
# flatten (Flatten)            (None, 144)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                9280
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                650
# =================================================================
# Total params: 14,058
# Trainable params: 14,058
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
history = model.fit(X_train, y_train_oh, epochs=20, batch_size=32, validation_data=(X_test, y_test_oh))
# Out:
# Epoch 1/20
# 1875/1875 [==============================] - 29s 16ms/step - loss: 0.6374 - accuracy: 0.7653 - val_loss: 0.5166 - val_accuracy: 0.8084
# Epoch 2/20
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.4468 - accuracy: 0.8375 - val_loss: 0.4584 - val_accuracy: 0.8309
# Epoch 3/20
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.3936 - accuracy: 0.8556 - val_loss: 0.4209 - val_accuracy: 0.8503
# Epoch 4/20
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.3631 - accuracy: 0.8655 - val_loss: 0.3844 - val_accuracy: 0.8579
# Epoch 5/20
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.3403 - accuracy: 0.8729 - val_loss: 0.3722 - val_accuracy: 0.8649
# Epoch 6/20
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.3235 - accuracy: 0.8798 - val_loss: 0.3739 - val_accuracy: 0.8647
# Epoch 7/20
# 1875/1875 [==============================] - 34s 18ms/step - loss: 0.3101 - accuracy: 0.8848 - val_loss: 0.3722 - val_accuracy: 0.8686
# Epoch 8/20
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.2997 - accuracy: 0.8882 - val_loss: 0.3488 - val_accuracy: 0.8747
# Epoch 9/20
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.2891 - accuracy: 0.8916 - val_loss: 0.3617 - val_accuracy: 0.8721
# Epoch 10/20
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.2826 - accuracy: 0.8933 - val_loss: 0.3462 - val_accuracy: 0.8757
# Epoch 11/20
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.2746 - accuracy: 0.8967 - val_loss: 0.3377 - val_accuracy: 0.8785
# Epoch 12/20
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.2661 - accuracy: 0.9003 - val_loss: 0.3393 - val_accuracy: 0.8816
# Epoch 13/20
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.2596 - accuracy: 0.9031 - val_loss: 0.3462 - val_accuracy: 0.8742
# Epoch 14/20
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.2543 - accuracy: 0.9046 - val_loss: 0.3452 - val_accuracy: 0.8799
# Epoch 15/20
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.2494 - accuracy: 0.9054 - val_loss: 0.3419 - val_accuracy: 0.8821
# Epoch 16/20
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.2433 - accuracy: 0.9085 - val_loss: 0.3574 - val_accuracy: 0.8785
# Epoch 17/20
# 1875/1875 [==============================] - 29s 15ms/step - loss: 0.2383 - accuracy: 0.9107 - val_loss: 0.3446 - val_accuracy: 0.8800
# Epoch 18/20
# 1875/1875 [==============================] - 29s 16ms/step - loss: 0.2329 - accuracy: 0.9122 - val_loss: 0.3572 - val_accuracy: 0.8762
# Epoch 19/20
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.2296 - accuracy: 0.9130 - val_loss: 0.3491 - val_accuracy: 0.8834
# Epoch 20/20
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.2250 - accuracy: 0.9156 - val_loss: 0.3627 - val_accuracy: 0.8786

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
